# %%
while True:
    try:
        nom_fichier = input("Entrer le nom complet du fichier : ")

        fichier = open(f"../data/{nom_fichier}", "r")
        break
    except FileNotFoundError:
        print("Fichier non trouvé.")
        reponse = input("Voulez-vous réessayer ? (y/n) ")
        if reponse=='n':
            break

# %%
print("Que voulez-vous faire ? ")
print("\t1 : Lire ")
print("\t2 : Écrire à la suite ")
print("\t3 : Remplacer le contenu ")
reponse = input("Votre choix : ")
if reponse == "1":
    with open(f"../data/{nom_fichier}", "r") as f:
        fichier = f.read()
        print(fichier)
elif reponse == "2":
    contenu = input("Saisissez le texte à ajouter : ")
    with open(f"../data/{nom_fichier}", 'a') as f:
        f.write(contenu)
elif reponse == "3":
    contenu = input("Saisissez le nouveau texte : ")
    with open(f"../data/{nom_fichier}", 'w') as f:
        f.write(contenu)
# Out:
# Que voulez-vous faire ?
# 	1 : Lire
# 	2 : Écrire à la suite
# 	3 : Remplacer le contenu
# Bonjour à tous !
