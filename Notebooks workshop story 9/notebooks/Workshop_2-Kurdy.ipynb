# %% [markdown]
# # Chat ou Chien !! une méthode d'apprentissage automatique.
#
# Dans une entreprise de marketing, on veut faire une étude sur les clients qui fréquentent un grand magasin. L'idée est d'estimer le pourcentage de clients qui ont des chats et ceux qui ont des chiens, afin de prendre des décisions marketing ciblées. Vous proposez d'utiliser une caméra pour détecter et compter les deux animaux dans le magasin. La première étape du projet est de développer un modèle qui peut détecter le chat ou le chien. Ainsi, dans ce brief, en utilisant une base de données, vous allez entrainer un modèle d'apprentissage automatique avec un apprentissage supervisé.

# %% [markdown]
# # Veille technologique: Opencv python
#
# - Préparation données imagerie pour méthode classique d'apprentissage automatique
# - Entrainement et évaluation (similaire aux briefs précédents)

# %% [markdown]
# ## Operations Simples

# %%
# use opencv to load and display the image
import os
import cv2
import numpy as np

# %%
# Préparer data 
size = 150
# repertoir d'images avec deux sous dossiers "Cat" et "Dog"
image_directory = '../PetImages/'
images = []  # liste pour images  
label = []  # liste pour Label (0 ou 1) pour deux classes.

# utiliser "os" pour avoir les noms des images dans chaque sous dossier

# utiliser une boucle pour lire chaque image, redimensionner en (150,150,3),
# et la mettre dans images, et mettre le label(0 ou 1) selon le type dans "label"

# il y a des images corrumpues, utiliser try ... catch except pour les ignorer

# boucle pour les images Cat
folder_cat = image_directory+"Cat"
for cat in os.listdir(folder_cat):
    full_directory = os.path.join(folder_cat, cat)
    try:
        image_cat = cv2.imread(full_directory)
        resized = cv2.resize(image_cat, (150, 150))
        images.append(resized)
        label.append(0)
    except:
        pass

# boucle pour les images Dog   
folder_dog = image_directory+"Dog"
for dog in os.listdir(folder_dog):
    full_directory = os.path.join(folder_dog, dog)
    try:
        image_dog = cv2.imread(full_directory)
        resized = cv2.resize(image_dog, (150, 150))
        images.append(resized)
        label.append(1)
    except:
        pass

# transformer les listes en numpy 
images = np.array(images)
label = np.array(label)

# save data as ".npy" file
np.save(file="../data/images.npy", arr=images, allow_pickle=True)
np.save(file="../data/label.npy", arr=label, allow_pickle=True)

# show shape
print(images.shape)
print(label.shape)
# Out:
# (24996, 150, 150, 3)
# (24996,)

# %%
# prepare data for classical machine learning model

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# utiliser reshape pour redimensionner les données images (exemple: (120,150,150,3) ---> (120,150*150*3)
n_images = images.shape[0]
new_dim = 150 * 150 * 3

# Transformation en 2D
images_flat = images.reshape(n_images, new_dim)

print(f"Ancienne forme : {images.shape}")
print(f"Nouvelle forme pour RF : {images_flat.shape}")

# split les données en train et test avec "stratification"
# Découpage : 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(
    images_flat, 
    label, 
    test_size=0.2, 
    stratify=label,  # Garde l'équilibre entre les classes
    random_state=42  # Pour la reproductibilité
)

print(f"Taille de X_train : {X_train.shape}")
print(f"Taille de X_test : {X_test.shape}")
# Out:
# Ancienne forme : (24996, 150, 150, 3)
# Nouvelle forme pour RF : (24996, 67500)
# Taille de X_train : (19996, 67500)
# Taille de X_test : (5000, 67500)

# %%
# initialiser le classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# entrainer le classifier
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# evaluate classifier
from sklearn.metrics import classification_report
# predire
pred = rf_model.predict(X_test)
# evaluer avec classification_report
print(classification_report(y_true=y_test, y_pred=pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67      2500
#            1       0.68      0.60      0.64      2500
#
#     accuracy                           0.66      5000
#    macro avg       0.66      0.66      0.65      5000
# weighted avg       0.66      0.66      0.65      5000

# %% [markdown]
# ### Essayer de normaliser chaque image entre 0 et 255 et rentrainer le modèle. Y a-t-il une amélioration ?

# %%
# Conversion en float pour permettre les décimales, puis division
images_norm = images.astype('float32') / 255.0

print(images_norm.min()) # Affiche 0.0
print(images_norm.max()) # Affiche 1.0
# Out:
# 0.0
# 1.0

# %%
# prepare data for classical machine learning model

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# utiliser reshape pour redimensionner les données images (exemple: (120,150,150,3) ---> (120,150*150*3)
n_images = images_norm.shape[0]
new_dim = 150 * 150 * 3

# Transformation en 2D
images_flat = images_norm.reshape(n_images, new_dim)

print(f"Ancienne forme : {images_norm.shape}")
print(f"Nouvelle forme pour RF : {images_flat.shape}")

# split les données en train et test avec "stratification"
# Découpage : 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(
    images_flat, 
    label, 
    test_size=0.2, 
    stratify=label,  # Garde l'équilibre entre les classes
    random_state=42  # Pour la reproductibilité
)

print(f"Taille de X_train : {X_train.shape}")
print(f"Taille de X_test : {X_test.shape}")
# Out:
# Ancienne forme : (24996, 150, 150, 3)
# Nouvelle forme pour RF : (24996, 67500)
# Taille de X_train : (19996, 67500)
# Taille de X_test : (5000, 67500)

# %%
# initialiser le classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# entrainer le classifier
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# evaluate classifier
from sklearn.metrics import classification_report
# predire
pred = rf_model.predict(X_test)
# evaluer avec classification_report
print(classification_report(y_true=y_test, y_pred=pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67      2500
#            1       0.67      0.60      0.63      2500
#
#     accuracy                           0.66      5000
#    macro avg       0.66      0.66      0.65      5000
# weighted avg       0.66      0.66      0.65      5000

# %% [markdown]
# # Neural networ MLP
#
# Entrainer un modèle MLP pour detecter la class Dog ou Cat.

# %%
# use PCA to reduce dimensions
# check this tuto: https://www.askpython.com/python/examples/principal-component-analysis-for-image-data

from keras.layers import Input, Dense, Dropout, Flatten
from keras.models import Model
from sklearn.decomposition import PCA

# On réduit à un nombre de composantes raisonnable (ex: 500 au lieu de 67500)
pca = PCA(n_components=500, random_state=42)

# On entraîne la PCA sur le train et on l'applique au test
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print(f"Nouvelle dimension après PCA : {X_train_pca.shape[1]}")

# creer un reseau de neurone avec une couche d'entrée de taille (150*150*3), deux couches caché de taille 128 et une activation "relu". 
# Dernière couche de taille 1 avec une activation sigmoid. Choisir la bonne "loss function" et "optimizer"
# Taille d'entrée basée sur le nombre de composantes PCA
input_shape = (X_train_pca.shape[1],)

# Architecture
inputs = Input(shape=input_shape)

# Couches cachées
x = Dense(128, activation='relu')(inputs)
x = Dropout(0.2)(x) # Optionnel : pour éviter le surapprentissage
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)

# Couche de sortie (binaire : Cat vs Dog)
outputs = Dense(1, activation='sigmoid')(x)

# Assemblage du modèle
mlp_model = Model(inputs=inputs, outputs=outputs)

# Compilation
# Pour une classification binaire, la perte est "binary_crossentropy"
mlp_model.compile(
    optimizer="adam",
    loss='binary_crossentropy',
    metrics=['accuracy']
)

mlp_model.summary()
# Out:
# Nouvelle dimension après PCA : 500
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 500)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        64,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,769 (315.50 KB)
#  Trainable params: 80,769 (315.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# entrainer le modèle avec validation_split = 2, epochs = 20, et un batch_size = 128
history = mlp_model.fit(
    X_train_pca, y_train,
    validation_split=2,
    epochs=20,
    batch_size=128,
    validation_data=(X_test_pca, y_test)
)
# Out:
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5609 - loss: 0.7828 - val_accuracy: 0.6136 - val_loss: 0.6496
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6329 - loss: 0.6420 - val_accuracy: 0.6454 - val_loss: 0.6298
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6754 - loss: 0.5966 - val_accuracy: 0.6588 - val_loss: 0.6147
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7051 - loss: 0.5641 - val_accuracy: 0.6752 - val_loss: 0.6040
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7340 - loss: 0.5336 - val_accuracy: 0.6626 - val_loss: 0.6124
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7499 - loss: 0.5078 - val_accuracy: 0.6784 - val_loss: 0.6058
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7684 - loss: 0.4777 - val_accuracy: 0.6716 - val_loss: 0.6153
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7851 - loss: 0.4524 - val_accuracy: 0.6758 - val_loss: 0.6172
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7992 - loss: 0.4238 - val_accuracy: 0.6710 - val_loss: 0.6231
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.4002 - val_accuracy: 0.6758 - val_loss: 0.6335
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8296 - loss: 0.3762 - val_accuracy: 0.6726 - val_loss: 0.6510
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8425 - loss: 0.3530 - val_accuracy: 0.6816 - val_loss: 0.6693
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8517 - loss: 0.3348 - val_accuracy: 0.6762 - val_loss: 0.6859
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.3245 - val_accuracy: 0.6790 - val_loss: 0.6873
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8709 - loss: 0.2996 - val_accuracy: 0.6830 - val_loss: 0.7046
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8793 - loss: 0.2837 - val_accuracy: 0.6706 - val_loss: 0.7267
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8853 - loss: 0.2735 - val_accuracy: 0.6696 - val_loss: 0.7558
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.2618 - val_accuracy: 0.6706 - val_loss: 0.7615
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8963 - loss: 0.2486 - val_accuracy: 0.6728 - val_loss: 0.7741
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9031 - loss: 0.2384 - val_accuracy: 0.6720 - val_loss: 0.8059

# %%
# evaluate MLP
# evaluate classifier
from sklearn.metrics import classification_report
# predire
# X_test_pca doit avoir la même transformation PCA que celle appliquée au train
y_pred_probs = mlp_model.predict(X_test_pca)
y_pred = (y_pred_probs > 0.5).astype("int32")
# evaluer avec classification_report
print("Rapport de classification pour le MLP :")
print(classification_report(y_test, y_pred, target_names=['Cat', 'Dog']))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# Rapport de classification pour le MLP :
#               precision    recall  f1-score   support
#
#          Cat       0.66      0.70      0.68      2500
#          Dog       0.68      0.65      0.66      2500
#
#     accuracy                           0.67      5000
#    macro avg       0.67      0.67      0.67      5000
# weighted avg       0.67      0.67      0.67      5000

# %% [markdown]
# **Correction normalisation image entre 0 et 255**

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

img = cv2.imread('../PetImages/Dog/100.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

img = cv2.imread('../PetImages/Dog/100.jpg',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv2.imwrite('res.png',res)

plt.imshow(img,cmap='gray')
plt.show()
plt.imshow(equ,cmap='gray')
plt.show()

img2 = cv2.imread('res.png',0)
plt.imshow(img2,cmap='gray')
# Out:
# C:\Users\matthieu.catteyfaye\AppData\Local\Temp\ipykernel_5056\1275377135.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.flatten(),256,[0,256], color = 'r')
